# %% [markdown]
# # Description

# %% [markdown]
# This notebook is to explore the data generated by translating the titles and descriptions to English.

# %%
import data
import data_vectorizer
import nltk

# %% [markdown]
# # Number of text without spaces

# %%
data.topics.title_translate = data.topics.title_translate.map(data_vectorizer.transform_replace_line_breaks)
data.topics.description_translate = data.topics.description_translate.map(data_vectorizer.transform_replace_line_breaks)
data.contents.title_translate = data.contents.title_translate.map(data_vectorizer.transform_replace_line_breaks)
data.contents.description_translate = data.contents.description_translate.map(data_vectorizer.transform_replace_line_breaks)

def has_space(x):
    if type(x) == float:
        return False
    return x.find(" ") == -1

def count_space(x):
    if type(x) == float:
        return False
    return x.count(" ")

display(data.topics.loc[data.topics["title_translate"].map(has_space) & data.topics["description_translate"].map(has_space)])
display(data.contents.loc[data.contents["title_translate"].map(has_space) & data.contents["description_translate"].map(has_space)])
# Out:
#                           title        description channel category  level  \
# id
# t_02a1ca0d6eb0           पदार्थ    source_id=CRS13  217993   source      4
# t_051d27c50c2a          विद्युत    source_id=CRS11  217993   source      4
# t_06a08c383149        Practical   source_id=LES987  217993   source      4
# t_099929e28be3         Syllabus  source_id=LES1030  217993   source      4
# t_0c3b273c9766            ऊष्मा    source_id=CRS99  217993   source      4
# ...                         ...                ...     ...      ...    ...
# t_f416577b9240           बालगीत   source_id=CRS261  217993   source      3
# t_f6c2f2e3d78a             Game  source_id=LES1073  217993   source      3
# t_f84d49ce57c3            Sound  source_id=LES1298  217993   source      5
# t_faaab5eac455     Mobilization  source_id=LES1028  217993   source      4
# t_fe5d2b575f3c  बालगीत अंग्रेज़ी   source_id=LES972  217993   source      4
#
#                language          parent  has_content title_translate  \
# id
# t_02a1ca0d6eb0       hi  t_7f1b8596d09b        False       Substance
# t_051d27c50c2a       hi  t_7f1b8596d09b        False      Electrical
# t_06a08c383149       hi  t_c165ac72cf6b         True            Home
# t_099929e28be3       hi  t_b9d004bac488         True        Syllabus
# t_0c3b273c9766       hi  t_7f1b8596d09b        False         English
# ...                 ...             ...          ...             ...
# t_f416577b9240       hi  t_5d23f268087f        False            hair
# t_f6c2f2e3d78a       en  t_4250eee2b632         True            Game
# t_f84d49ce57c3       en  t_e5a55c3c7219         True           Sound
# t_faaab5eac455       hi  t_b9d004bac488         True    Mobilization
# t_fe5d2b575f3c       hi  t_f416577b9240         True         English
#
#                description_translate
# id
# t_02a1ca0d6eb0       source_id=CRS13
# t_051d27c50c2a       source_id=CRS11
# t_06a08c383149      source_id=LES987
# t_099929e28be3     source_id=LES1030
# t_0c3b273c9766       source_id=CRS99
# ...                              ...
# t_f416577b9240      source_id=CRS261
# t_f6c2f2e3d78a     source_id=LES1073
# t_f84d49ce57c3     source_id=LES1298
# t_faaab5eac455     source_id=LES1028
# t_fe5d2b575f3c      source_id=LES972
#
# [117 rows x 10 columns]
#                                                             title  \
# id
# c_00016694ea2a                   geometry-m3-topic-a-overview.pdf
# c_001c76404587                            ela-grade-12.lc.l27.pdf
# c_001de8c2670c  11.1-common-core-learning-stards-tool-11.1.1.l...
# c_00215dff851c  ela-g12-m2-unit-2-lesson-22-end-of-unit-assess...
# c_0024eda64cb9                            math-g3-m5-lesson-4.pdf
# ...                                                           ...
# c_ffabb8f79f63                           math-g1-m1-lesson-13.pdf
# c_ffba0b2fc67c                                 ela-11.3.2.l14.pdf
# c_ffd562e7ca96                                      10.2.3.L4.pdf
# c_ffd77915f588                    math-gk-m1-topic-a-lesson-1.pdf
# c_fff25b173a24        algebra-ii-m2-topic-b-lesson-11-student.pdf
#
#                                                       description      kind  \
# id
# c_00016694ea2a                   geometry-m3-topic-a-overview.pdf  document
# c_001c76404587                            ela-grade-12.lc.l27.pdf  document
# c_001de8c2670c  11.1-common-core-learning-stards-tool-11.1.1.l...  document
# c_00215dff851c  ela-g12-m2-unit-2-lesson-22-end-of-unit-assess...  document
# c_0024eda64cb9                            math-g3-m5-lesson-4.pdf  document
# ...                                                           ...       ...
# c_ffabb8f79f63                           math-g1-m1-lesson-13.pdf  document
# c_ffba0b2fc67c                                 ela-11.3.2.l14.pdf  document
# c_ffd562e7ca96                                      10.2.3.L4.pdf  document
# c_ffd77915f588                    math-gk-m1-topic-a-lesson-1.pdf  document
# c_fff25b173a24        algebra-ii-m2-topic-b-lesson-11-student.pdf  document
#
#                                                              text language  \
# id
# c_00016694ea2a  Estándares Comunes del Estado de Nueva York\n\...       es
# c_001c76404587  NYS Common Core ELA & Literacy Curriculum\n\nG...       es
# c_001de8c2670c  NYS Common Core ELA & Literacy Curriculum\n\nG...       es
# c_00215dff851c  NYS Common Core ELA & Literacy Curriculum\n\nD...       es
# c_0024eda64cb9  NYS COMMON CORE MATHEMATICS CURRICULUM\n\nLess...       es
# ...                                                           ...      ...
# c_ffabb8f79f63  NYS COMMON CORE MATHEMATICS CURRICULUM\n\nNomb...       es
# c_ffba0b2fc67c  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
# c_ffd562e7ca96  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
# c_ffd77915f588  Lesson 1 K•1\n\nNYS COMMON CORE MATHEMATICS CU...       en
# c_fff25b173a24  Lección 11\n\nPLAN DE ESTUDIOS DE MATEMÁTICAS ...       es
#
#                copyright_holder      license  \
# id
# c_00016694ea2a        Engage NY  CC BY-NC-SA
# c_001c76404587        Engage NY  CC BY-NC-SA
# c_001de8c2670c        Engage NY  CC BY-NC-SA
# c_00215dff851c        Engage NY  CC BY-NC-SA
# c_0024eda64cb9        Engage NY  CC BY-NC-SA
# ...                         ...          ...
# c_ffabb8f79f63        Engage NY  CC BY-NC-SA
# c_ffba0b2fc67c        Engage NY  CC BY-NC-SA
# c_ffd562e7ca96        Engage NY  CC BY-NC-SA
# c_ffd77915f588        Engage NY  CC BY-NC-SA
# c_fff25b173a24        Engage NY  CC BY-NC-SA
#
#                                                   title_translate  \
# id
# c_00016694ea2a                   geometry-m3-topic-a-overview.pdf
# c_001c76404587                            ela-grade-12.lc.l27.pdf
# c_001de8c2670c  11.1-common-core-learning-stards-tool-11.1.1.l...
# c_00215dff851c  ela-g12-m2-unit-2-lesson-22-end-of-unit-assess...
# c_0024eda64cb9                            math-g3-m5-lesson-4.pdf
# ...                                                           ...
# c_ffabb8f79f63                           math-g1-m1-lesson-13.pdf
# c_ffba0b2fc67c                                 ela-11.3.2.l14.pdf
# c_ffd562e7ca96                                      10.2.3.L4.pdf
# c_ffd77915f588                    math-gk-m1-topic-a-lesson-1.pdf
# c_fff25b173a24        algebra-ii-m2-topic-b-lesson-11-student.pdf
#
#                                             description_translate
# id
# c_00016694ea2a                   geometry-m3-topic-a-overview.pdf
# c_001c76404587                            ela-grade-12.lc.l27.pdf
# c_001de8c2670c  11.1-common-core-learning-stards-tool-11.1.1.l...
# c_00215dff851c  ela-g12-m2-unit-2-lesson-22-end-of-unit-assess...
# c_0024eda64cb9                            math-g3-m5-lesson-4.pdf
# ...                                                           ...
# c_ffabb8f79f63                           math-g1-m1-lesson-13.pdf
# c_ffba0b2fc67c                                 ela-11.3.2.l14.pdf
# c_ffd562e7ca96                                      10.2.3.L4.pdf
# c_ffd77915f588                    math-gk-m1-topic-a-lesson-1.pdf
# c_fff25b173a24        algebra-ii-m2-topic-b-lesson-11-student.pdf
#
# [2864 rows x 9 columns]

# %% [markdown]
# Seems like the text without any spaces are files or some source_id strings.

# %%
count = 2
display(data.topics.loc[(data.topics["title_translate"].map(count_space) == count) & (data.topics["description_translate"].map(count_space) == count)])
display(data.contents.loc[(data.contents["title_translate"].map(count_space) == count) & (data.contents["description_translate"].map(count_space) == count)])
# Out:
#                                          title  \
# id
# t_018999b150ab  Visualizations and Simulations
# t_0290c457b0dd            6: Memory management
# t_032ca6f99a91                   11: DC Offset
# t_061d53b02828            4: Assembler Program
# t_093a73fc019b                 7: Serial Lines
# ...                                        ...
# t_f74bcbbc78f3         4: Non-Renewable Energy
# t_fc2272487401              Khan for Educators
# t_fcb65d447ed5        3: Conditional Execution
# t_fdec6f02fe83           Números y Operaciones
# t_ff540badb419         7: Migration Strategies
#
#                                    description channel      category  level  \
# id
# t_018999b150ab  Visualizations and Simulations  cf94d5  supplemental      2
# t_0290c457b0dd            6: Memory management  88c9d6  supplemental      4
# t_032ca6f99a91                   11: DC Offset  88c9d6  supplemental      5
# t_061d53b02828            4: Assembler Program  88c9d6  supplemental      5
# t_093a73fc019b                 7: Serial Lines  88c9d6  supplemental      4
# ...                                        ...     ...           ...    ...
# t_f74bcbbc78f3         4: Non-Renewable Energy  88c9d6  supplemental      4
# t_fc2272487401              Khan for Educators  0ec697        source      1
# t_fcb65d447ed5        3: Conditional Execution  88c9d6  supplemental      4
# t_fdec6f02fe83           Números y Operaciones  998df9  supplemental      2
# t_ff540badb419         7: Migration Strategies  88c9d6  supplemental      4
#
#                language          parent  has_content  \
# id
# t_018999b150ab       en  t_cf16ab3856fa        False
# t_0290c457b0dd       en  t_64453d4bec61         True
# t_032ca6f99a91       en  t_5f15de1adafa         True
# t_061d53b02828       en  t_cf8b9e9c1e64         True
# t_093a73fc019b       en  t_9d54af939947         True
# ...                 ...             ...          ...
# t_f74bcbbc78f3       en  t_5c3939e9d518         True
# t_fc2272487401       en  t_b22641d12ddc        False
# t_fcb65d447ed5       en  t_c49e8be43970         True
# t_fdec6f02fe83       es  t_b16b428c3e57        False
# t_ff540badb419       en  t_c560be21573f         True
#
#                                title_translate           description_translate
# id
# t_018999b150ab  Visualizations and Simulations  Visualizations and Simulations
# t_0290c457b0dd            6: Memory management            6: Memory management
# t_032ca6f99a91                   11: DC Offset                   11: DC Offset
# t_061d53b02828            4: Assembler Program            4: Assembler Program
# t_093a73fc019b                 7: Serial Lines                 7: Serial Lines
# ...                                        ...                             ...
# t_f74bcbbc78f3         4: Non-Renewable Energy         4: Non-Renewable Energy
# t_fc2272487401              Khan for Educators              Khan for Educators
# t_fcb65d447ed5        3: Conditional Execution        3: Conditional Execution
# t_fdec6f02fe83          Numbers and Operations          Numbers and Operations
# t_ff540badb419         7: Migration Strategies         7: Migration Strategies
#
# [160 rows x 10 columns]
#                                                        title  \
# id
# c_00becbfcefee                     Enzyme kinetics questions
# c_01760f9578ab                 Multiplicar números negativos
# c_01eea12b16e5                     हर का परिमेयकरण (आधारभूत)
# c_07091a1eee9f                    Antibody class differences
# c_0746a97e8f16                                Era 7 Overview
# ...                                                      ...
# c_fbe9516c1e63  10.2.1 End-of-Unit Assessment_10.2.1.L20.pdf
# c_fc9ad8f1b398                               Ancient Aegean
# c_fcc79fd0548e     Mid-Unit Assessment Handout_9.4.1.L14.pdf
# c_fe876152317a     Forming Counterclaims Tool_11.3.2.L12.pdf
# c_feccba36b378                            Ribosome in action
#
#                                                  description      kind  \
# id
# c_00becbfcefee                     Enzyme kinetics questions  exercise
# c_01760f9578ab                 Practica multiplicar enteros.  exercise
# c_01eea12b16e5                     हर का परिमेयकरण (आधारभूत)  exercise
# c_07091a1eee9f                    Antibody Class Differences  exercise
# c_0746a97e8f16                          Test your knowledge!  exercise
# ...                                                      ...       ...
# c_fbe9516c1e63  10.2.1 End-of-Unit Assessment_10.2.1.L20.pdf  document
# c_fc9ad8f1b398                          Test your knowledge.  exercise
# c_fcc79fd0548e     Mid-Unit Assessment Handout_9.4.1.L14.pdf  document
# c_fe876152317a     Forming Counterclaims Tool_11.3.2.L12.pdf  document
# c_feccba36b378                        Nanotechnology at work     video
#
#                                                              text language  \
# id
# c_00becbfcefee                                                NaN       en
# c_01760f9578ab                                                NaN       es
# c_01eea12b16e5                                                NaN       hi
# c_07091a1eee9f                                                NaN       en
# c_0746a97e8f16                                                NaN       en
# ...                                                           ...      ...
# c_fbe9516c1e63  DRAFT\n\nNYS Common Core ELA & Literacy Curric...       es
# c_fc9ad8f1b398                                                NaN       en
# c_fcc79fd0548e  DRAFT\n\nNYS Common Core ELA & Literacy Curric...       es
# c_fe876152317a  DRAFT\n\nNYS Common Core ELA & Literacy Curric...       es
# c_feccba36b378                                                NaN       en
#
#                copyright_holder      license  \
# id
# c_00becbfcefee              NaN          NaN
# c_01760f9578ab              NaN          NaN
# c_01eea12b16e5              NaN          NaN
# c_07091a1eee9f              NaN          NaN
# c_0746a97e8f16              NaN          NaN
# ...                         ...          ...
# c_fbe9516c1e63        Engage NY  CC BY-NC-SA
# c_fc9ad8f1b398              NaN          NaN
# c_fcc79fd0548e        Engage NY  CC BY-NC-SA
# c_fe876152317a        Engage NY  CC BY-NC-SA
# c_feccba36b378              NaN          NaN
#
#                                              title_translate  \
# id
# c_00becbfcefee                     Enzyme kinetics questions
# c_01760f9578ab                     Multiply negative numbers
# c_01eea12b16e5                Peripheralization of everybody
# c_07091a1eee9f                    Antibody class differences
# c_0746a97e8f16                                Era 7 Overview
# ...                                                      ...
# c_fbe9516c1e63  10.2.1 End-of-Unit Assessment_10.2.1.L20.pdf
# c_fc9ad8f1b398                               Ancient Aegean
# c_fcc79fd0548e     Mid-Unit Assessment Handout_9.4.1.L14.pdf
# c_fe876152317a     Forming Counterclaims Tool_11.3.2.L12.pdf
# c_feccba36b378                            Ribosome in action
#
#                                        description_translate
# id
# c_00becbfcefee                     Enzyme kinetics questions
# c_01760f9578ab                Practice multiplying integers.
# c_01eea12b16e5                Peripheralization of everybody
# c_07091a1eee9f                    Antibody Class Differences
# c_0746a97e8f16                          Test your knowledge!
# ...                                                      ...
# c_fbe9516c1e63  10.2.1 End-of-Unit Assessment_10.2.1.L20.pdf
# c_fc9ad8f1b398                          Test your knowledge.
# c_fcc79fd0548e     Mid-Unit Assessment Handout_9.4.1.L14.pdf
# c_fe876152317a     Forming Counterclaims Tool_11.3.2.L12.pdf
# c_feccba36b378                        Nanotechnology at work
#
# [264 rows x 9 columns]

# %% [markdown]
# By inspecting count == 1 and count == 2, it seems better to replace "-" and "\_" with whitespaces to account for file names.

# %%
data.topics.title_translate = data.topics.title_translate.map(data_vectorizer.transform_replace_symbols)
data.topics.description_translate = data.topics.description_translate.map(data_vectorizer.transform_replace_symbols)
data.contents.title_translate = data.contents.title_translate.map(data_vectorizer.transform_replace_symbols)
data.contents.description_translate = data.contents.description_translate.map(data_vectorizer.transform_replace_symbols)

count = 1
display(data.topics.loc[data.topics["title_translate"].map(has_space) & data.topics["description_translate"].map(has_space)])
display(data.contents.loc[data.contents["title_translate"].map(has_space) & data.contents["description_translate"].map(has_space)])
display(data.topics.loc[(data.topics["title_translate"].map(count_space) == count) & (data.topics["description_translate"].map(count_space) == count)])
display(data.contents.loc[(data.contents["title_translate"].map(count_space) == count) & (data.contents["description_translate"].map(count_space) == count)])
# Out:
#                               title               description channel  \
# id
# t_0c6a9e4a6931             Genetics                  Genetics  ebc86c
# t_101c6d484a84                 漫画人物                      漫画人物  da1fa7
# t_11e7bc1103df                   BB                      v0.1  8bbad6
# t_1e105c86cef2              Squares                      v0.1  8bbad6
# t_1fd9e13d1c2d      مبرهنة فيثاغورس  5a4c84577dd19709085801b7  9fd860
# t_21e93273be86                    3                      v0.1  8bbad6
# t_2215e31ad1ba                 Text                      Text  ebc86c
# t_28d26a86de77               Metals                    Metals  88c9d6
# t_28d4a4606868              Algebra                   Algebra  1fb613
# t_2fb660683edc                    7                      v0.1  8bbad6
# t_33ea9c6a4c2d            Perimeter                      v0.1  8bbad6
# t_3d07aaaf7145             Chapters                  Chapters  88c9d6
# t_4058a21709ff             Chapters                  Chapters  88c9d6
# t_41898d41e152          Subtraction                      v0.1  8bbad6
# t_456cc1409529                    8                      v0.1  8bbad6
# t_4876adea5a7e          Experiments               Experiments  ebc86c
# t_4e8a32d80595            Magnetism                   Magnets  344113
# t_53a3e932bc98          Precalculus               Precalculus  1fb613
# t_79cf29145de0                 Area                      v0.1  8bbad6
# t_7e497b96ddf9             Calculus                  Calculus  1fb613
# t_8475bda63a66  Secadora de cabello       Secadora de cabello  36a98b
# t_8e54c06b7163                    5                      v0.1  8bbad6
# t_94f13fd3949e               Length                      v0.1  274269
# t_a34923b85518                    4                      v0.1  8bbad6
# t_a38a18c18de8                 Nets                      v0.1  8bbad6
# t_a6f7fe9d7c57           Commission                      v0.1  8bbad6
# t_ab6bf2e358fe          Subtraction                      v0.1  274269
# t_ad2de1d1fd84     القطوع المخروطية  5b9e5d886571f90499eaa796  9fd860
# t_ada4c193edf8             Discount                      v0.1  8bbad6
# t_b6b918fea826                    6                      v0.1  8bbad6
# t_b7661231559f            Perimeter                      v0.1  8bbad6
# t_b7a64e073078             Division                      v0.1  8bbad6
# t_bdfbba7029a9       Quadrilaterals                      v0.1  8bbad6
# t_c2f064fd9542           Insulators                Insulators  88c9d6
# t_ca051eacaa30                 Nets                      v0.1  274269
# t_cfe3088b6046       Multiplication                      v0.1  8bbad6
# t_d0b8b41a58c1   Mettre en équation        Mettre en équation  c152d6
# t_d26937ecbe3d                 Area                      v0.1  274269
# t_e508b2cd809f                   跳数                   几个几个地数数  f83dcf
# t_e6695cb0768e               Optics                    Optics  cf94d5
# t_ea2df1dd1574     Les pourcentages              Pourcentages  c152d6
#
#                     category  level language          parent  has_content  \
# id
# t_0c6a9e4a6931  supplemental      2       en  t_23ad2c3d0282        False
# t_101c6d484a84        source      2       zh  t_e105123ddb73        False
# t_11e7bc1103df  supplemental      1       en  t_fb7502ae1264        False
# t_1e105c86cef2  supplemental      4       en  t_d0cb31b1921b         True
# t_1fd9e13d1c2d        source      3       ar  t_9193112f04e6         True
# t_21e93273be86  supplemental      2       en  t_11e7bc1103df        False
# t_2215e31ad1ba  supplemental      3       en  t_8e8ef88e79d1        False
# t_28d26a86de77  supplemental      4       en  t_672bd71776af         True
# t_28d4a4606868  supplemental      2       en  t_5464b94c253c        False
# t_2fb660683edc  supplemental      2       en  t_11e7bc1103df        False
# t_33ea9c6a4c2d  supplemental      4       en  t_01ee6a4e74cc         True
# t_3d07aaaf7145  supplemental      4       en  t_a35665a51dd6         True
# t_4058a21709ff  supplemental      4       en  t_fa6937e17836         True
# t_41898d41e152  supplemental      4       en  t_2771a25fbfbb         True
# t_456cc1409529  supplemental      2       en  t_11e7bc1103df        False
# t_4876adea5a7e  supplemental      2       en  t_994411634648        False
# t_4e8a32d80595  supplemental      4       en  t_18c1cc3f4209        False
# t_53a3e932bc98  supplemental      2       en  t_7c43dafcb8af        False
# t_79cf29145de0  supplemental      4       en  t_41c81f99169f         True
# t_7e497b96ddf9  supplemental      2       en  t_7c43dafcb8af        False
# t_8475bda63a66        source      4       es  t_acd64758cfd2         True
# t_8e54c06b7163  supplemental      2       en  t_11e7bc1103df        False
# t_94f13fd3949e  supplemental      4       en  t_ecdf63c32511         True
# t_a34923b85518  supplemental      2       en  t_11e7bc1103df        False
# t_a38a18c18de8  supplemental      4       en  t_f3c1623a24bf         True
# t_a6f7fe9d7c57  supplemental      4       en  t_8d50d75d12dd         True
# t_ab6bf2e358fe  supplemental      4       en  t_1ff6e9be1d20         True
# t_ad2de1d1fd84        source      2       ar  t_5b4f3ba4eb7d         True
# t_ada4c193edf8  supplemental      4       en  t_8d50d75d12dd         True
# t_b6b918fea826  supplemental      2       en  t_11e7bc1103df        False
# t_b7661231559f  supplemental      4       en  t_41c81f99169f         True
# t_b7a64e073078  supplemental      4       en  t_f4d18a0ab250         True
# t_bdfbba7029a9  supplemental      4       en  t_7c2dc7f467aa         True
# t_c2f064fd9542  supplemental      4       en  t_672bd71776af         True
# t_ca051eacaa30  supplemental      4       en  t_b00ec6a2aa81        False
# t_cfe3088b6046  supplemental      4       en  t_f4d18a0ab250         True
# t_d0b8b41a58c1        source      4       fr  t_9c90802e1663         True
# t_d26937ecbe3d  supplemental      4       en  t_4950020cdf8c         True
# t_e508b2cd809f        source      4       zh  t_a7379647e871         True
# t_e6695cb0768e  supplemental      2       en  t_5f4ceaa6d7d7        False
# t_ea2df1dd1574        source      4       fr  t_320b75737da0         True
#
#                title_translate     description_translate
# id
# t_0c6a9e4a6931        Genetics                  Genetics
# t_101c6d484a84        Cartoons                  Cartoons
# t_11e7bc1103df              BB                      v0.1
# t_1e105c86cef2         Squares                      v0.1
# t_1fd9e13d1c2d     Vithagoras.   5a4c84577d19709085801b7
# t_21e93273be86               3                      v0.1
# t_2215e31ad1ba            Text                      Text
# t_28d26a86de77          Metals                    Metals
# t_28d4a4606868         Algebra                   Algebra
# t_2fb660683edc               7                      v0.1
# t_33ea9c6a4c2d       Perimeter                      v0.1
# t_3d07aaaf7145        Chapters                  Chapters
# t_4058a21709ff        Chapters                  Chapters
# t_41898d41e152     Subtraction                      v0.1
# t_456cc1409529               8                      v0.1
# t_4876adea5a7e     Experiments               Experiments
# t_4e8a32d80595       Magnetism                   Magnets
# t_53a3e932bc98     Precalculus               Precalculus
# t_79cf29145de0            Area                      v0.1
# t_7e497b96ddf9        Calculus                  Calculus
# t_8475bda63a66       Hairdryer                 Hairdryer
# t_8e54c06b7163               5                      v0.1
# t_94f13fd3949e          Length                      v0.1
# t_a34923b85518               4                      v0.1
# t_a38a18c18de8            Nets                      v0.1
# t_a6f7fe9d7c57      Commission                      v0.1
# t_ab6bf2e358fe     Subtraction                      v0.1
# t_ad2de1d1fd84     Conecutors.  5b9e5d886571f90499eaa796
# t_ada4c193edf8        Discount                      v0.1
# t_b6b918fea826               6                      v0.1
# t_b7661231559f       Perimeter                      v0.1
# t_b7a64e073078        Division                      v0.1
# t_bdfbba7029a9  Quadrilaterals                      v0.1
# t_c2f064fd9542      Insulators                Insulators
# t_ca051eacaa30            Nets                      v0.1
# t_cfe3088b6046  Multiplication                      v0.1
# t_d0b8b41a58c1        Equation                  Equation
# t_d26937ecbe3d            Area                      v0.1
# t_e508b2cd809f          Divide                 Plurality
# t_e6695cb0768e          Optics                    Optics
# t_ea2df1dd1574     Percentages               Percentages
#                         title               description      kind  \
# id
# c_00a888e2a1d2  9.2.1.L10.pdf             9.2.1.L10.pdf  document
# c_011eb3c737f4        التقييم  5b48f76c45dea204a15d5fd2  exercise
# c_022d04664c52        التقييم  5a4cc1b27dd197047d770cd3  exercise
# c_022d79ca4133  6m1.texts.pdf             6m1.texts.pdf  document
# c_02692eff3670  9.4.1.L15.pdf             9.4.1.L15.pdf  document
# ...                       ...                       ...       ...
# c_fed6b1840120   9.2.2.L5.pdf              9.2.2.L5.pdf  document
# c_ff0f7c51f410  9.4.1.L14.pdf             9.4.1.L14.pdf  document
# c_ff11e3220a96        التقييم  5a54c9057dd197717bd4b0bb  exercise
# c_ffa369b8cf72  10.3.2.L4.pdf             10.3.2.L4.pdf  document
# c_ffd562e7ca96  10.2.3.L4.pdf             10.2.3.L4.pdf  document
#
#                                                              text language  \
# id
# c_00a888e2a1d2  NYS Common Core ELA & Literacy Curriculum\n\n9...       es
# c_011eb3c737f4  ناتج ![](${☣ CONTENTSTORAGE}/1c4be6c0d78fd3805...       ar
# c_022d04664c52  عدد محاور التماثل (التناظر) للشكل التالي تساوي...       ar
# c_022d79ca4133  Grade 6: Module 1\nRecommended Texts\nThis wor...       es
# c_02692eff3670  NYS Common Core ELA & Literacy Curriculum\n\n9...       es
# ...                                                           ...      ...
# c_fed6b1840120  NYS Common Core ELA & Literacy Curriculum\n\n9...       es
# c_ff0f7c51f410  NYS Common Core ELA & Literacy Curriculum\n\n9...       es
# c_ff11e3220a96  قم بحل المتباينة لإيجاد مجموعة الحل  \n![](${☣...       ar
# c_ffa369b8cf72  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
# c_ffd562e7ca96  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
#
#                copyright_holder      license title_translate  \
# id
# c_00a888e2a1d2        Engage NY  CC BY-NC-SA   9.2.1.L10.pdf
# c_011eb3c737f4           Edraak  CC BY-NC-SA      Evaluation
# c_022d04664c52           Edraak  CC BY-NC-SA      Evaluation
# c_022d79ca4133        Engage NY  CC BY-NC-SA   6m1.texts.pdf
# c_02692eff3670        Engage NY  CC BY-NC-SA   9.4.1.L15.pdf
# ...                         ...          ...             ...
# c_fed6b1840120        Engage NY  CC BY-NC-SA    9.2.2.L5.pdf
# c_ff0f7c51f410        Engage NY  CC BY-NC-SA   9.4.1.L14.pdf
# c_ff11e3220a96           Edraak  CC BY-NC-SA      Evaluation
# c_ffa369b8cf72        Engage NY  CC BY-NC-SA   10.3.2.L4.pdf
# c_ffd562e7ca96        Engage NY  CC BY-NC-SA   10.2.3.L4.pdf
#
#                    description_translate
# id
# c_00a888e2a1d2             9.2.1.L10.pdf
# c_011eb3c737f4  5b48f76c45dea204a15d5fd2
# c_022d04664c52   5a4cc1b27d197047d770cd3
# c_022d79ca4133             6m1.texts.pdf
# c_02692eff3670             9.4.1.L15.pdf
# ...                                  ...
# c_fed6b1840120              9.2.2.L5.pdf
# c_ff0f7c51f410             9.4.1.L14.pdf
# c_ff11e3220a96  5a54c9057dd197717bd4b0bb
# c_ffa369b8cf72             10.3.2.L4.pdf
# c_ffd562e7ca96             10.2.3.L4.pdf
#
# [471 rows x 9 columns]
#                          title       description channel      category  level  \
# id
# t_004c82e65ed6   हॅलो पिरियड्स  source_id=CRS211  217993        source      4
# t_005db937bae8      1: Objects        1: Objects  88c9d6  supplemental      4
# t_007fb58bdafd     Back Matter       Back Matter  88c9d6  supplemental      5
# t_02996777856e    Front Matter      Front Matter  88c9d6  supplemental      4
# t_02b9e80bc0c0     Back Matter       Back Matter  88c9d6  supplemental      4
# ...                        ...               ...     ...           ...    ...
# t_fd5a65dc8634       मानव शरीर   source_id=CRS14  217993        source      4
# t_fe9d92f2fc6e    Front Matter      Front Matter  88c9d6  supplemental      4
# t_feb8a9252623      16: Arrays        16: Arrays  88c9d6  supplemental      4
# t_fed40e464649      10: Tuples        10: Tuples  88c9d6  supplemental      4
# t_ff76cdb6bcb7  5: Photodiodes    5: Photodiodes  88c9d6  supplemental      5
#
#                language          parent  has_content title_translate  \
# id
# t_004c82e65ed6       hi  t_62e6e9f76f40        False   Halo Pierceds
# t_005db937bae8       en  t_ba72040b9cb4         True      1: Objects
# t_007fb58bdafd       en  t_49922a6ab305         True     Back Matter
# t_02996777856e       en  t_123a733b479d         True    Front Matter
# t_02b9e80bc0c0       en  t_579449f88871         True     Back Matter
# ...                 ...             ...          ...             ...
# t_fd5a65dc8634       hi  t_7f1b8596d09b        False      Human Body
# t_fe9d92f2fc6e       en  t_f37f4cfc337d         True    Front Matter
# t_feb8a9252623       en  t_ba72040b9cb4         True      16: Arrays
# t_fed40e464649       en  t_c49e8be43970         True      10: Tuples
# t_ff76cdb6bcb7       en  t_c82d069236e1         True  5: Photodiodes
#
#                description_translate
# id
# t_004c82e65ed6      source id=CRS211
# t_005db937bae8            1: Objects
# t_007fb58bdafd           Back Matter
# t_02996777856e          Front Matter
# t_02b9e80bc0c0           Back Matter
# ...                              ...
# t_fd5a65dc8634       source id=CRS14
# t_fe9d92f2fc6e          Front Matter
# t_feb8a9252623            16: Arrays
# t_fed40e464649            10: Tuples
# t_ff76cdb6bcb7        5: Photodiodes
#
# [384 rows x 10 columns]
#                                  title  \
# id
# c_005a9bd02c41      ela-11.4.2.l14.pdf
# c_01cf080bba71                小数比较的应用题
# c_02571b26fd19                   Video
# c_041a0cd03cd4                   Video
# c_04e93e0c1c3a                   Video
# ...                                ...
# c_f9702fa7fbfc  Biosignaling questions
# c_fbbd864b57e6                   Video
# c_fe639bda3595    Baba Baba Black Ship
# c_ff918759ec8d      ela-11.4.2.l21.pdf
# c_ffba0b2fc67c      ela-11.3.2.l14.pdf
#
#                                                       description      kind  \
# id
# c_005a9bd02c41                                 ela-11.4.2.l14.pdf  document
# c_01cf080bba71                                           小数比较的应用题  exercise
# c_02571b26fd19                           5ad487673a891b049e2d13dc     video
# c_041a0cd03cd4                           5ad4a895f342d704a625511e     video
# c_04e93e0c1c3a                           5acc93433a891b049e29d6fe     video
# ...                                                           ...       ...
# c_f9702fa7fbfc                             Biosignaling questions  exercise
# c_fbbd864b57e6                           5ad47f9ff342d704a6253256     video
# c_fe639bda3595  source_url=http://www.prathamopenschool.org/Co...     video
# c_ff918759ec8d                                 ela-11.4.2.l21.pdf  document
# c_ffba0b2fc67c                                 ela-11.3.2.l14.pdf  document
#
#                                                              text language  \
# id
# c_005a9bd02c41  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
# c_01cf080bba71                                                NaN       zh
# c_02571b26fd19                                                NaN       ar
# c_041a0cd03cd4                                                NaN       ar
# c_04e93e0c1c3a                                                NaN       ar
# ...                                                           ...      ...
# c_f9702fa7fbfc                                                NaN       en
# c_fbbd864b57e6                                                NaN       ar
# c_fe639bda3595                                                NaN       hi
# c_ff918759ec8d  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
# c_ffba0b2fc67c  NYS Common Core ELA & Literacy Curriculum\n\n1...       es
#
#                copyright_holder      license         title_translate  \
# id
# c_005a9bd02c41        Engage NY  CC BY-NC-SA      ela 11.4.2.l14.pdf
# c_01cf080bba71              NaN          NaN    Smaller applications
# c_02571b26fd19              NaN          NaN                  Vide o
# c_041a0cd03cd4              NaN          NaN                  Vide o
# c_04e93e0c1c3a              NaN          NaN                  Vide o
# ...                         ...          ...                     ...
# c_f9702fa7fbfc              NaN          NaN  Biosignaling questions
# c_fbbd864b57e6              NaN          NaN                  Vide o
# c_fe639bda3595              NaN          NaN         Baba's Blessing
# c_ff918759ec8d        Engage NY  CC BY-NC-SA      ela 11.4.2.l21.pdf
# c_ffba0b2fc67c        Engage NY  CC BY-NC-SA      ela 11.3.2.l14.pdf
#
#                                             description_translate
# id
# c_005a9bd02c41                                 ela 11.4.2.l14.pdf
# c_01cf080bba71                               Smaller applications
# c_02571b26fd19                          5ad487673a891b049e2d13d c
# c_041a0cd03cd4                          5ad4a895f342d704a625511 e
# c_04e93e0c1c3a                          5acc93433a891b049e29d6f e
# ...                                                           ...
# c_f9702fa7fbfc                             Biosignaling questions
# c_fbbd864b57e6                          5ad47f9ff342d704a 6253256
# c_fe639bda3595  source url=http://www.prathamopenschool.org/Co...
# c_ff918759ec8d                                 ela 11.4.2.l21.pdf
# c_ffba0b2fc67c                                 ela 11.3.2.l14.pdf
#
# [239 rows x 9 columns]

# %% [markdown]
# # Attempt for applying lemmatizer to vectorize

# %%
print(data_vectorizer.lemmatize_sentence(data.topics.loc["t_00068291e9a4", "description_translate"]))
# Out:
# ['understand', 'little', 'more', 'function']

# %%
display(data.topics)
# Out:
#                                                             title  \
# id
# t_00004da3a1b2                         Откриването на резисторите
# t_000095e03056             Unit 3.3 Enlargements and Similarities
# t_00068291e9a4                    Entradas e saídas de uma função
# t_00069b63a70a                                        Transcripts
# t_0006d41a73a8  Графики на експоненциални функции (Алгебра 2 н...
# ...                                                           ...
# t_fffb0bf2801d                             4.3 Graph of functions
# t_fffbe1d5d43c                   Inscribed shapes problem solving
# t_fffe14f1be1e                                          Lección 7
# t_fffe811a6da9  تحديد العلاقة بين الإحداثيّات القطبية والإحداث...
# t_fffe88835149  Formation of shadows and eclipses (umbra and p...
#
#                                                       description channel  \
# id
# t_00004da3a1b2  Изследване на материали, които предизвикват на...  000cf7
# t_000095e03056                                                NaN  b3f329
# t_00068291e9a4               Entenda um pouco mais sobre funções.  8e286a
# t_00069b63a70a                                                NaN  6e3ba4
# t_0006d41a73a8  Научи повече за графиките на сложните показате...  000cf7
# ...                                                           ...     ...
# t_fffb0bf2801d                                                NaN  e77b55
# t_fffbe1d5d43c  Use properties of inscribed angles to prove pr...  0c929f
# t_fffe14f1be1e                                                NaN  6e90a7
# t_fffe811a6da9                           5b9e5ca86571f90499ea987f  9fd860
# t_fffe88835149                                                NaN  c7ca13
#
#                category  level language          parent  has_content  \
# id
# t_00004da3a1b2   source      4       bg  t_16e29365b50d         True
# t_000095e03056  aligned      2       en  t_aa32fb6252dc        False
# t_00068291e9a4   source      4       pt  t_d14b6c2a2b70         True
# t_00069b63a70a   source      3       en  t_4054df11a74e         True
# t_0006d41a73a8   source      4       bg  t_e2452e21d252         True
# ...                 ...    ...      ...             ...          ...
# t_fffb0bf2801d  aligned      4       en  t_676e6a1a4dc7        False
# t_fffbe1d5d43c   source      4       sw  t_50145b9bab3f         True
# t_fffe14f1be1e  aligned      6       es  t_d448c707984d         True
# t_fffe811a6da9   source      2       ar  t_5b4f3ba4eb7d         True
# t_fffe88835149  aligned      4       en  t_988923176459        False
#
#                                                   title_translate  \
# id
# t_00004da3a1b2                                                NaN
# t_000095e03056             Unit 3.3 Enlargements and Similarities
# t_00068291e9a4                   Inputs and outputs of a function
# t_00069b63a70a                                        Transcripts
# t_0006d41a73a8                                                NaN
# ...                                                           ...
# t_fffb0bf2801d                             4.3 Graph of functions
# t_fffbe1d5d43c                                                NaN
# t_fffe14f1be1e                                           Lesson 7
# t_fffe811a6da9  Identification of the relationship between Arc...
# t_fffe88835149  Formation of shadows and eclipses (umbra and p...
#
#                                     description_translate
# id
# t_00004da3a1b2                                        NaN
# t_000095e03056                                        NaN
# t_00068291e9a4  Understand a little more about functions.
# t_00069b63a70a                                        NaN
# t_0006d41a73a8                                        NaN
# ...                                                   ...
# t_fffb0bf2801d                                        NaN
# t_fffbe1d5d43c                                        NaN
# t_fffe14f1be1e                                        NaN
# t_fffe811a6da9                   5b9e5ca86571f90499ea987f
# t_fffe88835149                                        NaN
#
# [76972 rows x 10 columns]

# %% [markdown]
# # Generate word frequency

# %%
import time
import pandas as pd
words_freq = dict()

def add_list_to_words_freq(mlist):
    for word in mlist:
        if word not in words_freq:
            words_freq[word] = 1
        else:
            words_freq[word] = words_freq[word] + 1

def obtain_lemmas(x):
    title = x["title_translate"]
    description = x["description_translate"]
    
    if type(title) != float:
        lems_title = data_vectorizer.lemmatize_sentence(title)
        add_list_to_words_freq(lems_title)
        
    if type(description) != float:
        lems_description = data_vectorizer.lemmatize_sentence(description)
        add_list_to_words_freq(lems_description)

ctime = time.time()
for index, row in data.topics.iterrows():
    obtain_lemmas(row)
ctime = time.time() - ctime
print("Time elapsed: ",ctime)

ctime = time.time()
for index, row in data.contents.iterrows():
    obtain_lemmas(row)
ctime = time.time() - ctime
print("Time elapsed: ",ctime)

# convert to series
words_freq = pd.Series(words_freq).sort_values(ascending = False)

words_frame = pd.DataFrame(index = range(len(words_freq)))
words_frame["word"] = words_freq.index
words_frame["frequency"] = words_freq.values
words_frame.to_csv("data/word_freqs.csv")
# Out:
# Time elapsed:  102.20474863052368

# %%
display(data_vectorizer.word_freqs)
# Out:
#                               word  frequency
# 0                               be      58406
# 1                           lesson      23708
# 2                            learn      22275
# 3                              use      19559
# 4                            video      17263
# ...                            ...        ...
# 50406  phosphorylation/v/oxidative          1
# 50407       fermentation/oxidative          1
# 50408                      mirando          1
# 50409                  invalidated          1
# 50410                          7.4          1
#
# [50411 rows x 2 columns]

# %%
import pandas as pd
inverse = pd.DataFrame(index = data_vectorizer.word_freqs["word"], data = data_vectorizer.word_freqs.index, columns = ["pos"])

# %%
display(inverse["pos"].loc[inverse.index.intersection(["use","be", "rwrfeg"])])
# Out:
# word
# be     0
# use    3
# Name: pos, dtype: int64

# %%
data_vectorizer.vectorize("geometry-m3-topic-a-overview.pdf")
# Out:
# [10, 183, 440, 1310]

# %% [markdown]
# # Obtain a list of learnable words

# %%
def is_learnable(x):
    title_vector = data_vectorizer.vectorize(x["title_translate"])
    desc_vector = data_vectorizer.vectorize(x["description_translate"])
    return len(title_vector) + len(desc_vector) > 0

learnable_topics = data.topics.apply(is_learnable, axis = 1)
learnable_contents = data.contents.apply(is_learnable, axis = 1)
learnable_topics.to_csv("data/learnable_topics.csv")
learnable_contents.to_csv("data/learnable_contents.csv")
