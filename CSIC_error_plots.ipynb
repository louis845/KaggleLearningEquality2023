# %%
import CSIC_reduction_plots

# %% [markdown]
# # Isomap

# %%
CSIC_reduction_plots.isomap_embedding_plot()
# Out:
# float32
# Loaded topics data with shape:  (76972, 768)
# Finished first isomap in  174.9379563331604  seconds.
# Finished n_components =  20  in  893.2679209709167  seconds.
# Finished n_components =  40  in  881.2758502960205  seconds.
# Finished n_components =  60  in  878.5421953201294  seconds.
# Finished n_components =  80  in  878.1695189476013  seconds.
# Finished n_components =  100  in  870.5993220806122  seconds.
# Finished n_components =  120  in  866.1445121765137  seconds.
# Finished n_components =  140  in  862.913604259491  seconds.
# Finished n_components =  160  in  824.1752374172211  seconds.
# Finished n_components =  180  in  824.1053454875946  seconds.
# Finished n_components =  200  in  824.5657603740692  seconds.
# Finished n_components =  220  in  825.8418774604797  seconds.
# Finished n_components =  240  in  826.3723745346069  seconds.
# Finished n_components =  260  in  826.5542166233063  seconds.
# ...

# %% [markdown]
# # LTSA

# %%
CSIC_reduction_plots.ltsa_embedding_plot()
# Out:
# float32
# Loaded topics data with shape:  (76972, 768)
# Finished first ltsa in  22.05596685409546  seconds.
# Finished n_components =  20  in  66.28014779090881  seconds.
# Finished n_components =  40  in  117.00582528114319  seconds.
# Finished n_components =  60  in  258.4117729663849  seconds.
# Finished n_components =  80  in  261.8338747024536  seconds.
# Finished n_components =  100  in  382.90923738479614  seconds.
# Finished n_components =  120  in  487.8745529651642  seconds.
# Finished n_components =  140  in  579.5054545402527  seconds.
# Finished n_components =  160  in  686.5275638103485  seconds.
# Finished n_components =  180  in  822.3817851543427  seconds.
# Finished n_components =  200  in  1039.0930008888245  seconds.
# Finished n_components =  220  in  1130.7010507583618  seconds.
# Finished n_components =  240  in  1321.4980442523956  seconds.
# Finished n_components =  260  in  1542.546371936798  seconds.
# ...
