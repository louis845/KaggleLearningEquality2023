# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown

# %%
def data_readlog(filename):
    running_data = pd.read_csv("../models/"+filename+"/logfile.csv", index_col = 0)

# %%
filename=input("enter file name=")

# %%
data_readlog(filename)

# %%
data_len=len(running_data)
display(running_data[["test_precision", "test_recall"]])
# Out:
#        test_precision  test_recall
# epoch
# 0            0.543322     0.600673
# 1            0.586752     0.670222
# 2            0.603186     0.716100
# 3            0.615485     0.747921
# 4            0.627361     0.766887
# ...               ...          ...
# 164          0.800047     0.800547
# 165          0.800253     0.800302
# 166          0.800402     0.800114
# 167          0.800583     0.799928
# 168          0.800802     0.799589
#
# [169 rows x 2 columns]

# %%
running_data[["test_precision", "test_recall"]].plot(figsize = (30, 30))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mini_val=1
for k in range(data_len):
    
    if round(running_data.loc[k].at["test_precision"]-running_data.loc[k].at["test_recall"],5)<mini_val:
        mini_val=abs(running_data.loc[k].at["test_precision"]-running_data.loc[k].at["test_recall"])
        mini_epoch=k
        
print("optimal epoch for mini= " + str(mini_epoch))
print("value of test_precision and test_recall= "+ str(mini_val))
# Out:
# optimal epoch for mini= 165
# value of test_precision and test_recall= 4.947185516357422e-05

# %%
running_data[["test_precision", "test_recall"]].plot(figsize = (30, 30))
plt.axvline(x=mini_epoch)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
display((running_data.loc[mini_epoch]))
# Out:
# accuracy                                        0.927507
# entropy                                         0.179934
# entropy_large_set                               0.241151
# precision                                       0.890655
# recall                                          0.974744
# test_accuracy                                   0.800256
# test_accuracy_nolang                            0.759256
# test_entropy                                    0.433917
# test_entropy_nolang                             0.507137
# test_in_train_sample_accuracy                   0.783823
# test_in_train_sample_accuracy_nolang            0.733910
# test_in_train_sample_entropy                    0.471654
# test_in_train_sample_entropy_nolang             0.565615
# test_in_train_sample_precision                  0.793820
# test_in_train_sample_precision_nolang           0.735457
# test_in_train_sample_recall                     0.767078
# ...

# %%
max_val70=0
for k in range(data_len):
    
    if running_data.loc[k].at["test_precision"]<=0.7:
        continue
    
    elif running_data.loc[k].at["test_precision"]>0.7 and running_data.loc[k].at["test_recall"] > max_val70:
    
        max_val70=running_data.loc[k].at["test_recall"]
        max_epoch70=k

print("optimal epoch for test_precision>0.7 = " + str(max_epoch70))
print("value of test_recall= "+ str(max_val70))
# Out:
# optimal epoch for test_precision>0.7 = 32
# value of test_recall= 0.830939769744873

# %%
display((running_data.loc[max_epoch70]))
# Out:
# accuracy                                        0.875893
# entropy                                         0.282502
# entropy_large_set                               0.357830
# precision                                       0.833026
# recall                                          0.940336
# test_accuracy                                   0.767826
# test_accuracy_nolang                            0.727961
# test_entropy                                    0.468934
# test_entropy_nolang                             0.531353
# test_in_train_sample_accuracy                   0.752371
# test_in_train_sample_accuracy_nolang            0.705617
# test_in_train_sample_entropy                    0.497080
# test_in_train_sample_entropy_nolang             0.570614
# test_in_train_sample_precision                  0.730814
# test_in_train_sample_precision_nolang           0.684804
# test_in_train_sample_recall                     0.799404
# ...

# %%
running_data[["test_precision", "test_recall"]].plot(figsize = (30, 30))
plt.axvline(x=max_epoch)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
max_val75=0
for k in range(data_len):
    
    if running_data.loc[k].at["test_precision"]<=0.75:
        continue
    
    elif running_data.loc[k].at["test_precision"]>0.75 and running_data.loc[k].at["test_recall"] > max_val75:
    
        max_val75=running_data.loc[k].at["test_recall"]
        max_epoch75=k

print("optimal epoch for test_precision>0.7 = " + str(max_epoch75))
print("value of test_recall= "+ str(max_val75))
# Out:
# optimal epoch for test_precision>0.7 = 42
# value of test_recall= 0.8300603032112122

# %%
display((running_data.loc[max_epoch75]))
# Out:
# accuracy                                        0.885533
# entropy                                         0.261849
# entropy_large_set                               0.337960
# precision                                       0.845028
# recall                                          0.944292
# test_accuracy                                   0.777134
# test_accuracy_nolang                            0.735061
# test_entropy                                    0.455326
# test_entropy_nolang                             0.522427
# test_in_train_sample_accuracy                   0.761579
# test_in_train_sample_accuracy_nolang            0.712253
# test_in_train_sample_entropy                    0.484471
# test_in_train_sample_entropy_nolang             0.563864
# test_in_train_sample_precision                  0.743879
# test_in_train_sample_precision_nolang           0.693606
# test_in_train_sample_recall                     0.798190
# ...
