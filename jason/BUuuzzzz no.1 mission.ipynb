# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown

# %%
running_data = pd.read_csv("../models/direct_model/logfile.csv", index_col = 0)  # use packages to read the data here
# REMEMBER the index_col set to be 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35092\525661310.py in <module>
# ----> 1 running_data = pd.read_csv("../models/direct_model/logfile.csv", index_col = 0)  # use packages to read the data here
#       2 # REMEMBER the index_col set to be 0
#
# NameError: name 'pd' is not defined

# %%
display(running_data[["test_precision", "test_recall"]])
# Out:
#        test_precision  test_recall
# epoch
# 0            0.552459     0.714152
# 1            0.590820     0.741338
# 2            0.612372     0.760646
# 3            0.627897     0.776062
# 4            0.641936     0.784904
# ...               ...          ...
# 73           0.804227     0.777122
# 74           0.804943     0.776259
# 75           0.805581     0.775520
# 76           0.806226     0.774705
# 77           0.806817     0.774016
#
# [78 rows x 2 columns]

# %%
running_data[["test_precision", "test_recall"]].plot(figsize = (30, 30))
plt.axvline(x=55)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
running_data.loc[0].at["test_precision"]
# Out:
# 0.5524585247039795

# %%
mini_val=1
for k in range(78):
    
    if abs(running_data.loc[k].at["test_precision"]-running_data.loc[k].at["test_recall"])<mini_val:
        mini_val=abs(running_data.loc[k].at["test_precision"]-running_data.loc[k].at["test_recall"])
        z=k
        
print(z)
print(mini_val)
# Out:
# 55
# 5.662441253662109e-06

# %%
print((running_data.loc[k].at["test_precision"],running_data.loc[k].at["test_recall"]))
# Out:
# (0.772517204284668, 0.8016730546951294)

# %%
g.refline(39,
          color = "red",
          lw = 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27828\2955807476.py in <module>
# ----> 1 g.refline(39,
#       2           color = "red",
#       3           lw = 3)
#
# AttributeError: 'AxesSubplot' object has no attribute 'refline'

# %%
display((running_data.loc[55]))
# Out:
# accuracy                        0.936807
# entropy                         0.159588
# entropy_large_set               0.250206
# precision                       0.899686
# recall                          0.983255
# test_accuracy                   0.790267
# test_accuracy_nolang            0.754621
# test_entropy                    0.455127
# test_entropy_nolang             0.516060
# test_precision                  0.790281
# test_precision_nolang           0.740461
# test_recall                     0.790286
# test_recall_nolang              0.784123
# test_square_accuracy            0.905763
# test_square_accuracy_nolang     0.873859
# test_square_entropy             0.217335
# test_square_entropy_nolang      0.284293
# test_square_precision           0.868131
# test_square_precision_nolang    0.835944
# test_square_recall              0.956891
# test_square_recall_nolang       0.930310
# Name: 55, dtype: float64
